# %% [markdown]
# <a href="https://colab.research.google.com/github/jemimaprins/pythonPractise/blob/main/pythonPractise.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
Blah blah

# %%
#code here
x = 1+1
print(x)
# Out:
# 2

# %%
#Jemimas code here
import matplotlib.pyplot as plt
import numpy as np
m=1
x=2
c=3
y = m*x + c
fig,ax = plt.subplots()
ax.plot(x,y)
plt.show()
